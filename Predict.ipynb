# %%
from SFlib_II import *

data=r'data\SiHits_3D_pvar_0.02_10000_v2.txt'
# event0=915 #9989

# 初始化
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')


# 读取文件
# [0event number, 1track number, track 2px, 3py, 4pz, hit 5x, 6y,7z]
df = pd.read_csv(data, header=None)
# 显示前几行数据以确认读取正确
# print(df.head(50))




cc_s=[]
cc_s_p=[]
cc_s_r=[]

# 装载 r p_T 预备训练
# r特征为 t=[[r0,e0],...]
r0_s=[]
t=[]
p_T=[]
pt_s=[]
checkout=[]

#     0  1  2       3       4       5       6       7       8
# 0   0  0  0  0.0495  0.0522 -0.0526  0.7370  0.6745 -0.7309
# 1   0  0  1  0.0495  0.0522 -0.0526  1.5798  1.2243 -1.4622

# event0=346
# print(f"event {event0}")

# 单个event
# i0=0+event0*100
totalevent=10000
for i0 in range(totalevent):
    nowevent=i0
    # i0=0+event0*100
    if not i0%50:
        print(f"event {i0}")
    a_s=[]
    for i in range(20):
        for j in range(5):
            a_s_p=df.iloc[i0, :].tolist()
            # a_s.append([a_s_p[1]]+a_s_p[3:]+c_to_p(a_s_p[6],a_s_p[7]))##这里改动
            a_s.append([a_s_p[0:3]]+a_s_p[3:]+c_to_p(a_s_p[6],a_s_p[7]))##这里改动
            # a_ss.append(a_s_p)
            i0+=1



    # print(a_s)

    ###############
    # 总分析绘图

        # plt.plot(z2, r2, 'go')
        # r-z线段
        # for i in range(len(rs)):
        #     # print(rs[i][0][2:4],rs[i][1][2:4])
        #     drawln2d(rs[i][0][2:4],rs[i][1][2:4],ax=plt)
            # drawln2d([z00,0],b_s[i][2:4],ax=plt)
            # drawln2d([-1.53792346,0],b_s[i][2:4],ax=plt)
        #####

    # 绘制rz
    # Drawrz(a_s)

    k_s=[]
    for i in range(len(a_s)):
        k,b = Findln([0,0],a_s[i][6:8])
        a_s[i].append(k)
        k_s.append(k)
        # print(k,b)

    a_s.sort(key=lambda x: x[-1])

    cp=categorize_points(a_s,0.001)
    # print(cp)

    # 绘制3d
    # Draw3Dscatter([a_s[i][4:7] for i in range(len(a_s))],ax=ax,color='b')
    # ax.scatter(0,0,0, c='r', marker='o')
    # ax.title(f"event {event0}\ndata: {data}")

    # for i in range(len(cp)):#画线
    #     cl = random_color()
    #     if len(cp[i])>5: print(i)
    #     for j in range(len(cp[i])-1):
    #         drawln3d(cp[i][j][:3], cp[i][j+1][:3], ax=ax, color=cl)

    # plt.show()

    # 绘制斜率分布
    # plt.figure()
    # plt.scatter(k_s,[0]*len(k_s))

    # 绘制xOy投影
    # plt.figure()
    # plt.scatter([a_s[i][4] for i in range(len(a_s))],[a_s[i][5] for i in range(len(a_s))])
    # # for i in range(len(cp)):#画线
    # #     cl = random_color()
    # #     if len(cp[i])>5: print(i)
    # #     for j in range(len(cp[i])-1):
    # #         drawln2d(cp[i][j][:2], cp[i][j+1][:2], ax=plt, color=cl)
    # plt.axis('equal') # 设置等比例

    # plt.figure()
    # print('cp',cp)


    # 统计量放在这里
    for j in range(len(cp)):#拟合
        color=random_color()
        # print(cp[j][1])
        # print([cp[j][i][4:6] for i in range(len(cp[j]))])
        ccx,ccy,r0,e0 = FitCircle([cp[j][i][4:6] for i in range(len(cp[j]))],delta_r=[1,2,3,5,7],draw=False,ax=plt)
        r0_s.append([ccx,ccy])
        cc_s.append(np.sqrt(cp[j][2][1]**2+cp[j][2][2]**2)/r0)
        pt_s.append(np.sqrt(cp[j][2][1]**2+cp[j][2][2]**2))
        cc_s_p.append([np.sqrt(cp[j][2][1]**2+cp[j][2][2]**2),cp[j][2][1],cp[j][2][2]])
        cc_s_r.append(r0)
        t.append([r0]+e0)
        p_T.append([cp[j][1][1],cp[j][1][2]])
        checkout.append(cp[j][0])
        # DrawEllipse([ccx,ccy], cp[j], r0, ax=ax, color=color)

print(f"event {nowevent} | finished")


# plt.figure()
# plt.hist(cc_s,bins=550)
# print(cc_s_r)
# print(cc_s_p)
# plt.title(r"Using $p_{xOy,\text{real}}/r_\text{predicted}$")
# print(cc_s)
# plt.show()
# t
# Out:
# event 0
# event 50
# event 100
# event 150
# event 200
# event 250
# event 300
# event 350
# event 400
# event 450
# event 500
# event 550
# event 600
# event 650
# event 700
# event 750
# event 800
# event 850
# event 900
# event 950
# event 1000
# event 1050
# event 1100
# event 1150
# event 1200
# event 1250
# event 1300
# event 1350
# event 1400
# event 1450
# event 1500
# event 1550
# event 1600
# event 1650
# event 1700
# event 1750
# event 1800
# event 1850
# event 1900
# event 1950
# event 2000
# event 2050
# event 2100
# event 2150
# event 2200
# event 2250
# event 2300
# event 2350
# event 2400
# event 2450
# event 2500
# event 2550
# event 2600
# event 2650
# event 2700
# event 2750
# event 2800
# event 2850
# event 2900
# event 2950
# event 3000
# event 3050
# event 3100
# event 3150
# event 3200
# event 3250
# event 3300
# event 3350
# event 3400
# event 3450
# event 3500
# event 3550
# event 3600
# event 3650
# event 3700
# event 3750
# event 3800
# event 3850
# event 3900
# event 3950
# event 4000
# event 4050
# event 4100
# event 4150
# event 4200
# event 4250
# event 4300
# event 4350
# event 4400
# event 4450
# event 4500
# event 4550
# event 4600
# event 4650
# event 4700
# event 4750
# event 4800
# event 4850
# event 4900
# event 4950
# event 5000
# event 5050
# event 5100
# event 5150
# event 5200
# event 5250
# event 5300
# event 5350
# event 5400
# event 5450
# event 5500
# event 5550
# event 5600
# event 5650
# event 5700
# event 5750
# event 5800
# event 5850
# event 5900
# event 5950
# event 6000
# event 6050
# event 6100
# event 6150
# event 6200
# event 6250
# event 6300
# event 6350
# event 6400
# event 6450
# event 6500
# event 6550
# event 6600
# event 6650
# event 6700
# event 6750
# event 6800
# event 6850
# event 6900
# event 6950
# event 7000
# event 7050
# event 7100
# event 7150
# event 7200
# event 7250
# event 7300
# event 7350
# event 7400
# event 7450
# event 7500
# event 7550
# event 7600
# event 7650
# event 7700
# event 7750
# event 7800
# event 7850
# event 7900
# event 7950
# event 8000
# event 8050
# event 8100
# event 8150
# event 8200
# event 8250
# event 8300
# event 8350
# event 8400
# event 8450
# event 8500
# event 8550
# event 8600
# event 8650
# event 8700
# event 8750
# event 8800
# event 8850
# event 8900
# event 8950
# event 9000
# event 9050
# event 9100
# event 9150
# event 9200
# event 9250
# event 9300
# event 9350
# event 9400
# event 9450
# event 9500
# event 9550
# event 9600
# event 9650
# event 9700
# event 9750
# event 9800
# event 9850
# event 9900
# event 9950
# event 9999 | finished

# %%
r=r0_s

p=p_T

n=len(r)

r=np.array(r)
t0=np.array(t)
t0[:,1:]*=1000
t=t0[:,1:]
p=np.array(p)
p*=100

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error

# 生成示例数据
X1,X2 = r,t
y=p
# 将输入数据展平为二维
X_flattened=np.concatenate((X1, X2), axis=1)
# X_flattened = X.reshape(100, -1)

# 划分训练集和测试集
test_size = 0.3
X_train, X_test, y_train, y_test = train_test_split(X_flattened, y, test_size=test_size)

# 数据标准化
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


# 创建 MLP 回归模型
mlp = MLPRegressor(hidden_layer_sizes=(90, 90),activation='tanh',
                   solver='adam', max_iter=1200)

# 训练模型
print("Training the model...")
mlp.fit(X_train, y_train)
print("Model trained!")

# 预测
y_pred = mlp.predict(X_test)

# 评估模型
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")

# 可视化结果
plt.figure(figsize=(12, 6))

# 绘制第一个目标值的实际值和预测值
# plt.subplot(1, 2, 1)
plt.scatter(y_test[:, 0],y_test[:, 1], color='blue', label='Actual')
plt.scatter(y_pred[:, 0],y_pred[:, 1], color='red', label='Predicted',s=15)
plt.title(f'vectors matching scatter plot | total: {totalevent}\ndataset: {data}\nMSE: {mse:.6f} | test_size: {test_size}')
plt.xlabel(r'$p_x$')
plt.ylabel(r'$p_y$')
plt.legend()
plt.savefig('figure_partII_MSE.png',bbox_inches="tight", dpi=800)
# Out:
# Training the model...
# Model trained!
# Mean Squared Error: 0.018715056245365562

# %%
# 生成直方图
# 目标
trains=np.array(pt_s)
# 再训练
tests=mlp.predict(scaler.transform(X_flattened))/100
# 求模长
testsr0=[np.sqrt(tests[i][0]**2+tests[i][1]**2) for i in range(len(tests))]
want=testsr0/trains
notwant=np.array([np.sqrt(i[0]**2+i[1]**2) for i in r0_s])/testsr0/100
with open('testsr0.txt','w') as f:
    f.write("pT_actual\n")
    f.write(str(list(trains)))
    f.write("\npT_predicted\n")
    f.write(str(testsr0))

print(sorted(testsr0))

# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
# # matplotlib.rcParams['mathtext.default'] = 'regular'
# fig.suptitle(r"$r_{\text{fitted}}/p_{T,\text{true}}$ vs $p_{T,\text{predicted}}/p_{T,\text{true}}$"f'\ndata: {data}', y=1.16)
# fig.subplots_adjust(wspace=0.4)  # 增加 wspace 的值来加大子图间的距离
# ax1.ylabel("Frequency")
# ax2.set_ylabel("Frequency")

# ax1.hist(notwant,bins=60,edgecolor='black',color='purple',range=(0.8,1.2))
# ax1.xlabel(r"$r_{\text{fitted}}/p_{T,\text{true}}$")
# ax1.title(r"Using $r_{\text{fitted}}/p_{T,\text{true}}$"f"\nstd = {np.std(notwant):.8f}")

# ax2.hist(want,bins=60,edgecolor='black',color='purple',range=(0.9,1.1))
# ax2.set_xlabel(r"${p_{T,\text{predicted}}} / {p_{T,\text{real}}}$")
# ax2.set_title(r"Using $p_{T,\text{predicted}}/p_{T,\text{true}}$"f"\nstd = {np.std(want):.8f}")

# 四子图
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 8))
fig.suptitle(r"$r_{\text{fitted}}/p_{T,\text{true}}$ vs $p_{T,\text{predicted}}/p_{T,\text{true}}$"f'\ndata: {data}', y=1.05)
fig.subplots_adjust(wspace=0.4, hspace=0.5)  # 调整子图之间的水平和垂直间距

# 第一行保持不变
ax1.hist(notwant, bins=60, edgecolor='black', color='purple',range=(0.8,1.2))
ax1.set_xlabel(r"$\frac{r_{\text{fitted}}}{100}/p_{T,\text{true}}$")
ax1.set_ylabel("Frequency")
ax1.set_title(r"Using $\frac{r_{\text{fitted}}}{100}/p_{T,\text{true}}$"f"\nstd = {np.std(notwant):.8f}")

ax2.hist(want, bins=60, edgecolor='black', color='purple',range=(0.8,1.2))
ax2.set_xlabel(r"${p_{T,\text{predicted}}} / {p_{T,\text{real}}}$")
ax2.set_ylabel("Frequency")
ax2.set_title(r"Using $p_{T,\text{predicted}}/p_{T,\text{true}}$"f"\nstd = {np.std(want):.8f}")

# 新增第二行子图
ax3.hist(notwant, bins=60, edgecolor='black', color='purple',range=(0.8,1.2))
ax3.set_xlabel(r"$\frac{r_{\text{fitted}}}{100}/p_{T,\text{true}}$")
ax3.set_ylabel("Frequency~log")
ax3.set_yscale('log')  # 设置y轴为对数比例
ax3.set_title(r"Log-scale $\frac{r_{\text{fitted}}}{100}/p_{T,\text{true}}$")

ax4.hist(want, bins=60, edgecolor='black', color='purple',range=(0.8,1.2))
ax4.set_xlabel(r"${p_{T,\text{predicted}}} / {p_{T,\text{real}}}$")
ax4.set_ylabel("Frequency~log")
ax4.set_yscale('log')  # 设置y轴为对数比例
ax4.set_title(r"Log-scale $p_{T,\text{predicted}}/p_{T,\text{true}}$")



# ax1.savefig('figure_partII_1.png',bbox_inches="tight", dpi=800)
# ax2.savefig('figure_partII_2.png',bbox_inches="tight", dpi=800)
# ax3.savefig('figure_partII_3.png',bbox_inches="tight", dpi=800)
# ax4.savefig('figure_partII_4.png',bbox_inches="tight", dpi=800)
plt.savefig('figure_partII.png',bbox_inches="tight", dpi=800)


plt.show()
# Out:
# [np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.03778381846722692), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.038142708436195924), np.float64(0.03 ...

# %%
# 再绘图
# 第一行保持不变
plt.hist(notwant, bins=40, edgecolor='black', color='purple',range=(0.8,1.2))
plt.xlabel(r"$\frac{r_{\text{fitted}}}{100}/p_{T,\text{true}}$")
plt.ylabel("Frequency")
plt.title(r"Using $\frac{r_{\text{fitted}}}{100}/p_{T,\text{true}}$"f"\nstd = {np.std(notwant):.8f}")
plt.savefig('figure_partII_1.png',bbox_inches="tight", dpi=800)

plt.hist(want, bins=40, edgecolor='black', color='purple',range=(0.8,1.2))
plt.xlabel(r"${p_{T,\text{predicted}}} / {p_{T,\text{real}}}$")
plt.ylabel("Frequency")
plt.title(r"Using $p_{T,\text{predicted}}/p_{T,\text{true}}$"f"\nstd = {np.std(want):.8f}")
plt.savefig('figure_partII_2.png',bbox_inches="tight", dpi=800)

# 新增第二行子图
plt.hist(notwant, bins=40, edgecolor='black', color='purple',range=(0.8,1.2))
plt.xlabel(r"$\frac{r_{\text{fitted}}}{100}/p_{T,\text{true}}$")
plt.ylabel("Frequency~log")
plt.yscale('log')  # 设置y轴为对数比例
plt.title(r"Log-scale $\frac{r_{\text{fitted}}}{100}/p_{T,\text{true}}$")
plt.savefig('figure_partII_3.png',bbox_inches="tight", dpi=800)

plt.hist(want, bins=40, edgecolor='black', color='purple',range=(0.8,1.2))
plt.xlabel(r"${p_{T,\text{predicted}}} / {p_{T,\text{real}}}$")
plt.ylabel("Frequency~log")
plt.yscale('log')  # 设置y轴为对数比例
plt.title(r"Log-scale $p_{T,\text{predicted}}/p_{T,\text{true}}$")
plt.savefig('figure_partII_4.png',bbox_inches="tight", dpi=800)

# %%
print([[i,want[i]] for i in range(len(want)) if want[i]<0.9 or want[i]>1.4])
# print(checkout[])
# print()
# Out:
# [[7, np.float64(0.7254020548598049)], [26, np.float64(0.7254020548598049)], [45, np.float64(0.7254020548598049)], [64, np.float64(0.7254020548598049)], [83, np.float64(0.7254020548598049)], [103, np.float64(0.7254020548598049)], [123, np.float64(0.7254020548598049)], [142, np.float64(0.7254020548598049)], [161, np.float64(0.7254020548598049)], [180, np.float64(0.7254020548598049)], [199, np.float64(0.7